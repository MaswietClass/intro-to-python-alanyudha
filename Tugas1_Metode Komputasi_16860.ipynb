# %% [markdown]
# # Tugas 1
# 1. Sebutkan 3 jenis tipe variabel di dalam Python
#     - Jawab : *integer* ('int'),*float* ('float'),*string* ('str'). *Integer* merupakan variabel berisikan bilangan bulat. *Float* merupakan variabel yang berisikan bilangan cacah. Sedangkan *string* merupakan variabel yang berisikan karakter.
# 2. Jelaskan mengapa di Python ada aturan Indentation?
#     - Jawab : Dalam Python dikenal yang namanya Function, dalam suatu Function pasti memiliki **header** dan **body**. Suatu **header** akan diakhiri dengan tanda titik dua ':'. Sedangkan untuk **body** harus diberi indentasi sejumlah 4 space. Hal ini bertujuan untuk memisahkan perintah Function yang terdapat pada **header** dan statement yang terdapat pada **body**.

# %%
#Membuat Program sederhana pengecek bilangan genap atau ganjil#
print("Halo :)")
print("Selamat datang di program pengecek bilangan genap atau ganjil")
print("")
x = int(input("Masukkan Angka :"))
print("")
if x % 2 == 0 :
    print("Bilangan Genap")
    
else :
    print("Bilangan Ganjil")
# Out:
# Halo :)
# Selamat datang di program pengecek bilangan genap atau ganjil
#
# Masukkan Angka :999
#
# Bilangan Ganjil
